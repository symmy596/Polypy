# %%
from polypy import Read as rd
from polypy import Density as Dens
from polypy import MSD as msd
from polypy import Write as wr
import numpy as np

# %%
Atom = "F"
timestep = 0.25
data = rd.read_history("../../../OLD/data/HISTORY_F", ["CA", "F"])

# %%
atom_data = rd.get_atom(data, "F")

# %%
msd_data = msd.msd(atom_data, timestep)
wr.msd_plot(msd_data)

# %%
atom_data = rd.get_atom(data, "CA")
msd_data = msd.msd(atom_data, timestep)
wr.msd_plot(msd_data)

# %%
data = rd.read_history("../../../OLD/data/HISTORY_F", ["CA"])
msd_data = msd.msd(data, timestep)
wr.msd_plot(msd_data)

# %%
data = rd.read_history("../../../OLD/data/HISTORY_F", ["F"])
msd_data = msd.msd(data, timestep)
wr.msd_plot(msd_data)
